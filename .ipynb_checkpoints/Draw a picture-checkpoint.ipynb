# %%
from Picture.create_picture import Picture

# %%
img = Picture(600, 500, [0,0,0])
img.dragon(200,200,400,400,17,[225,176,17])
img.picture
# Out:
# <PIL.Image.Image image mode=RGB size=600x500 at 0x7F059C4E9198>

# %%
img = Picture(500, 500, [40,100,250])

img.draw_square(400, 0, 500, 500, [10,255,10])
img.draw_disc(300,300,80,[230,30,30])

img.draw_circle(300,300,80,[0,0,0])
img.draw_circle(300,300,79,[0,0,0])
img.draw_circle(300,300,78,[0,0,0])
img.draw_square(297, 220, 300, 381, [0,0,0])

img.draw_square(300, 220, 382, 381, [40,100,250])
img.draw_square(300, 280, 400, 320, [238,211,158])

img.picture
